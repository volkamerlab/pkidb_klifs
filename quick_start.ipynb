# %% [markdown]
# # Quick start notebook
#
# This notebook is meant as a quick start to loading two datasets:
# - PKIDB ligands
# - KLIFS ligands in clinical trails (= in PKIDB)

# %%
import pandas as pd

# %% [markdown]
# ## Load PKIDB ligands

# %%
pkidb_ligands = pd.read_csv('results/pkidb_20200218.csv', index_col=0)
pkidb_ligands
# Out:
#         INN_Name    BrandName  Phase                     Applicants LigID  \
# 0     Leniolisib          NaN    0.0                       Novartis   9NQ
# 1    Nemiralisib          NaN    0.0                GlaxosmithKline   VVX
# 2    Oclacitinib          NaN    0.0                         Pfizer   NaN
# 3      Toceranib          NaN    0.0                         Pfizer   NaN
# 4    Dezapelisib          NaN    0.0             Incyte Corporation   NaN
# ..           ...          ...    ...                            ...   ...
# 213    Ponatinib  ['Iclusig']    4.0          Ariad Pharmaceuticals   0LI
# 214    Lapatinib   ['Tykerb']    4.0                GlaxoSmithKline   FMM
# 215   Ribociclib  ['Kisqali']    4.0                       Novartis   6ZZ
# 216     Apatinib          NaN    4.0         Bukwang Pharmaceutical   NaN
# 217  Midostaurin   ['Rydapt']    4.0  Novartis Pharmaceuticals Corp   2K2
#
#                                                  pdbID  Type  RoF     MW  \
# 0                                             ['5o83']   NaN    0  450.2
# 1                                             ['5ae8']   NaN    0  440.2
# 2                                                  NaN   NaN    0  337.2
# 3                                                  NaN   NaN    0  396.2
# 4                                                  NaN   NaN    0  421.1
# ..                                                 ...   ...  ...    ...
# 213  ['3ik3', '3oxz', '3zos', '4c8b', '4qrc', '4tyj...   2.0    1  532.2
# 214                                   ['1xkk', '3bbt']   1.5    2  580.1
# 215                                           ['5l2t']   1.0    0  434.3
# 216                                                NaN   NaN    1  397.2
# 217                                           ['4nct']   NaN    2  570.2
#
#      LogP  ...                                            Targets  \
# 0     2.9  ...                                                NaN
# 1     4.9  ...                                                NaN
# 2     1.5  ...                           ['JAK1', 'JAK2', 'JAK3']
# 3     3.1  ...                                            ['KIT']
# 4     3.7  ...                                                NaN
# ..    ...  ...                                                ...
# 213   4.5  ...  ['ABL1', 'BCR', 'KIT', 'RET', 'TEK', 'FLT3', '...
# 214   6.1  ...                                  ['EGFR', 'ERBB2']
# 215   2.8  ...                                   ['CDK4', 'CDK6']
# 216   5.1  ...                                            ['KDR']
# 217   5.9  ...                                                NaN
#
#          Kinase_families  First_Approval      SC_Patent            Chirality  \
# 0                    NaN             NaN            NaN  Single Stereoisomer
# 1                    NaN             NaN            NaN  Single Stereoisomer
# 2                ['Tyr']             NaN            NaN  Single Stereoisomer
# 3                ['KIT']             NaN            NaN     Achiral Molecule
# 4                    NaN             NaN            NaN  Single Stereoisomer
# ..                   ...             ...            ...                  ...
# 213  ['Atypical', 'Tyr']          2012.0  US-8114874-B2     Achiral Molecule
# 214              ['Tyr']          2007.0  US-6391874-B1     Achiral Molecule
# 215             ['CMGC']          2017.0  US-8324225-B2     Achiral Molecule
# 216              ['Tyr']          2014.0            NaN                  NaN
# 217                  NaN          2017.0  US-7973031-B2  Single Stereoisomer
#
#                                               Synonyms FDA_approved  \
# 0                          ['CDZ173-NX', 'Leniolisib']          NaN
# 1        ['GSK2269557A', 'GSK-2269557', 'Nemiralisib']          NaN
# 2               ['Oclacitinib', 'JAKI', 'PF-03394197']          NaN
# 3                          ['PHA-291639', 'Toceranib']          NaN
# 4                        ['INCB040093', 'Dezapelisib']          NaN
# ..                                                 ...          ...
# 213               ['Iclusig', 'AP-24534', 'Ponatinib']            Y
# 214    ['Tyverb', 'GW-2016', 'GW-572016', 'Lapatinib']            Y
# 215            ['Ribociclib', 'LEE-011', 'NVP-LEE011']            Y
# 216  ['NO.', 'STUDY', 'DRUG', '5-FLUOROURACIL', 'VP...            N
# 217  ['Rydapt', 'Midostaurin', 'NVP-PKC412', 'PKC-4...            Y
#
#      Melting_points_C                                   Canonical_Smiles  \
# 0                 NaN  CCC(=O)N1CC[C@@H](C1)Nc2c3c(ncn2)CCN(C3)c4cc(c...
# 1                 NaN  CC(C)N1CCN(CC1)Cc2cnc(o2)c3cc(cc4c3cn[nH]4)c5c...
# 2                 NaN  CNS(=O)(=O)C[C@H]1CC[C@@H](CC1)N(c2ncnc3c2cc[n...
# 3                 NaN  Cc1c([nH]c(c1C(=O)NCCN2CCCC2)C)/C=C\3/c4cc(ccc...
# 4                 NaN  Cc1csc2n1c(=O)c(c(n2)[C@H](C)Nc3c4c([nH]cn4)nc...
# ..                ...                                                ...
# 213               NaN  Cc1ccc(cc1C#Cc2cnc3n2nccc3)C(=O)Nc4ccc(c(c4)C(...
# 214               NaN  CS(=O)(=O)CCNCc1ccc(o1)c2ccc3c(c2)c(ncn3)Nc4cc...
# 215               NaN  CN(C)C(=O)c1cc2cnc(nc2n1C3CCCC3)Nc4ccc(cn4)N5C...
# 216               NaN     N#CC1(CCCC1)c1ccc(cc1)NC(=O)c1cccnc1Nc1cnccc1C
# 217           235-260  C[C@@]12[C@@H]([C@@H](C[C@@H](O1)n3c4ccccc4c5c...
#
#                         InChIKey
# 0    MWKYMZXCGYXLPL-ZDUSSCGKSA-N
# 1    MCIDWGZGWVSZMK-UHFFFAOYSA-N
# 2    HJWLJNBZVZDLAQ-HAQNSBGRSA-N
# 3    SRSGVKWWVXWSJT-ATVHPVEESA-N
# 4    RSIWALKZYXPAGW-NSHDSACASA-N
# ..                           ...
# 213  PHXJVRSECIGDHY-UHFFFAOYSA-N
# 214  BCFGMOOMADDAQU-UHFFFAOYSA-N
# 215  RHXHGRAEPCAFML-UHFFFAOYSA-N
# 216  MGZNERAVOCFMCU-UHFFFAOYSA-N
# 217  BMGQWWVMWDBQGC-IIFHNQTCSA-N
#
# [218 rows x 25 columns]

# %% [markdown]
# ## Load KLIFS ligands in clinical trails

# %%
klifs_pki = pd.read_csv('results/klifs_pki_20200218.csv', index_col=0)
klifs_pki
# Out:
#                        InChIKey      INN_Name    BrandName  Phase  \
# 0   MWKYMZXCGYXLPL-ZDUSSCGKSA-N    Leniolisib          NaN    0.0
# 1   MCIDWGZGWVSZMK-UHFFFAOYSA-N   Nemiralisib          NaN    0.0
# 2   RZUOCXOYPYGSKL-GOSISDBHSA-N  Ravoxertinib          NaN    1.0
# 3   CGBJSGAELGCMKE-UHFFFAOYSA-N    Omipalisib          NaN    1.0
# 4   HKTBYUWLRDZAJK-UHFFFAOYSA-N  Tomivosertib          NaN    2.0
# ..                          ...           ...          ...    ...
# 94  KTUFNOKKBVMGRW-UHFFFAOYSA-N      Imatinib  ['Gleevec']    4.0
# 95  PHXJVRSECIGDHY-UHFFFAOYSA-N     Ponatinib  ['Iclusig']    4.0
# 96  BCFGMOOMADDAQU-UHFFFAOYSA-N     Lapatinib   ['Tykerb']    4.0
# 97  RHXHGRAEPCAFML-UHFFFAOYSA-N    Ribociclib  ['Kisqali']    4.0
# 98  BMGQWWVMWDBQGC-IIFHNQTCSA-N   Midostaurin   ['Rydapt']    4.0
#
#                        Applicants LigID  \
# 0                        Novartis   9NQ
# 1                 GlaxosmithKline   VVX
# 2                       Genentech   6QB
# 3                 GlaxosmithKline   ZIG
# 4           Effector Therapeutics   N45
# ..                            ...   ...
# 94                       Novartis   STI
# 95          Ariad Pharmaceuticals   0LI
# 96                GlaxoSmithKline   FMM
# 97                       Novartis   6ZZ
# 98  Novartis Pharmaceuticals Corp   2K2
#
#                                                 pdbID  Type  RoF     MW  ...  \
# 0                                            ['5o83']   NaN    0  450.2  ...
# 1                                            ['5ae8']   NaN    0  440.2  ...
# 2                            ['5k4i', '5k4j', '6oph']   NaN    0  440.1  ...
# 3                                            ['3l08']   1.0    1  505.1  ...
# 4                                            ['6ck6']   NaN    0  340.2  ...
# ..                                                ...   ...  ...    ...  ...
# 94  ['1iep', '1opj', '1t46', '1xbb', '2hyy', '2oiq...   2.0    0  493.3  ...
# 95  ['3ik3', '3oxz', '3zos', '4c8b', '4qrc', '4tyj...   2.0    1  532.2  ...
# 96                                   ['1xkk', '3bbt']   1.5    2  580.1  ...
# 97                                           ['5l2t']   1.0    0  434.3  ...
# 98                                           ['4nct']   NaN    2  570.2  ...
#
#               Chirality                                           Synonyms  \
# 0   Single Stereoisomer                        ['CDZ173-NX', 'Leniolisib']
# 1   Single Stereoisomer      ['GSK2269557A', 'GSK-2269557', 'Nemiralisib']
# 2   Single Stereoisomer            ['Ravoxertinib', 'RG-7842', 'GDC-0994']
# 3      Achiral Molecule                       ['Omipalisib', 'GSK2126458']
# 4                   NaN                             ['NK1', 'AND', 'MNK2']
# ..                  ...                                                ...
# 94     Achiral Molecule                 ['Gleevec', 'Imatinib', 'STI-571']
# 95     Achiral Molecule               ['Iclusig', 'AP-24534', 'Ponatinib']
# 96     Achiral Molecule    ['Tyverb', 'GW-2016', 'GW-572016', 'Lapatinib']
# 97     Achiral Molecule            ['Ribociclib', 'LEE-011', 'NVP-LEE011']
# 98  Single Stereoisomer  ['Rydapt', 'Midostaurin', 'NVP-PKC412', 'PKC-4...
#
#     FDA_approved  Melting_points_C  \
# 0            NaN               NaN
# 1            NaN               NaN
# 2            NaN               NaN
# 3            NaN               NaN
# 4            NaN               NaN
# ..           ...               ...
# 94             Y               226
# 95             Y               NaN
# 96             Y               NaN
# 97             Y               NaN
# 98             Y           235-260
#
#                                      Canonical_Smiles  \
# 0   CCC(=O)N1CC[C@@H](C1)Nc2c3c(ncn2)CCN(C3)c4cc(c...
# 1   CC(C)N1CCN(CC1)Cc2cnc(o2)c3cc(cc4c3cn[nH]4)c5c...
# 2   Cn1c(ccn1)Nc2nccc(n2)c3ccn(c(=O)c3)[C@H](CO)c4...
# 3   COc1c(cc(cn1)c2ccc3c(c2)c(ccn3)c4ccnnc4)NS(=O)...
# 4         Cc1cc(c(=O)n2c1C(=O)NC23CCCCC3)Nc4cc(ncn4)N
# ..                                                ...
# 94  Cc1ccc(cc1Nc2nccc(n2)c3cccnc3)NC(=O)c4ccc(cc4)...
# 95  Cc1ccc(cc1C#Cc2cnc3n2nccc3)C(=O)Nc4ccc(c(c4)C(...
# 96  CS(=O)(=O)CCNCc1ccc(o1)c2ccc3c(c2)c(ncn3)Nc4cc...
# 97  CN(C)C(=O)c1cc2cnc(nc2n1C3CCCC3)Nc4ccc(cn4)N5C...
# 98  C[C@@]12[C@@H]([C@@H](C[C@@H](O1)n3c4ccccc4c5c...
#
#                                                  Name PDB-code ligand_ID  \
# 0                                          Leniolisib      9NQ      2890
# 1   6-(1H-Indol-4-yl)-4-(5-{[4-(1-methylethyl)-1-p...      VVX      2646
# 2   1-[(1~{S})-1-(4-chloranyl-3-fluoranyl-phenyl)-...      6QB      2137
# 3   2,4-difluoro-N-[2-methoxy-5-(4-pyridazin-4-ylq...      ZIG      2501
# 4   6'-[(6-aminopyrimidin-4-yl)amino]-8'-methyl-2'...      N45      3108
# ..                                                ...      ...       ...
# 94  4-(4-METHYL-PIPERAZIN-1-YLMETHYL)-N-[4-METHYL-...      STI        48
# 95  3-(imidazo[1,2-b]pyridazin-3-ylethynyl)-4-meth...      0LI       136
# 96  N-{3-CHLORO-4-[(3-FLUOROBENZYL)OXY]PHENYL}-6-[...      FMM       239
# 97  7-cyclopentyl-N,N-dimethyl-2-{[5-(piperazin-1-...      6ZZ      2237
# 98                                             PKC412      2K2      1147
#
#                                         klifs_pdb_ids  \
# 0                                            ['5o83']
# 1                                            ['5ae8']
# 2                            ['6oph', '5k4j', '5k4i']
# 3                                            ['3l08']
# 4                                            ['6ck6']
# ..                                                ...
# 94  ['1t46', '3k5v', '6npv', '6hd4', '3gvu', '1iep...
# 95  ['4c8b', '4v04', '4qrc', '6tu9', '4u0i', '4v01...
# 96                                   ['1xkk', '3bbt']
# 97                                           ['5l2t']
# 98                                           ['4nct']
#
#                                                 ROMol
# 0   <img data-content="rdkit/molecule" src="data:i...
# 1   <img data-content="rdkit/molecule" src="data:i...
# 2   <img data-content="rdkit/molecule" src="data:i...
# 3   <img data-content="rdkit/molecule" src="data:i...
# 4   <img data-content="rdkit/molecule" src="data:i...
# ..                                                ...
# 94  <img data-content="rdkit/molecule" src="data:i...
# 95  <img data-content="rdkit/molecule" src="data:i...
# 96  <img data-content="rdkit/molecule" src="data:i...
# 97  <img data-content="rdkit/molecule" src="data:i...
# 98  <img data-content="rdkit/molecule" src="data:i...
#
# [99 rows x 30 columns]
