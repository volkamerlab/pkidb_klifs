# %% [markdown]
# # Example notebook
#
# This notebook is meant as a quick start to loading two datasets:
# - PKIDB ligands
# - KLIFS ligands in clinical trails (= in PKIDB)

# %%
import pandas as pd

# %% [markdown]
# ## Load PKIDB ligands

# %%
pkidb_ligands = pd.read_csv('results/pkidb_20200218.csv', index_col=0)
pkidb_ligands.head()
# Out:
#       INN_Name BrandName  Phase          Applicants LigID     pdbID  Type  \
# 0   Leniolisib       NaN    0.0            Novartis   9NQ  ['5o83']   NaN
# 1  Nemiralisib       NaN    0.0     GlaxosmithKline   VVX  ['5ae8']   NaN
# 2  Oclacitinib       NaN    0.0              Pfizer   NaN       NaN   NaN
# 3    Toceranib       NaN    0.0              Pfizer   NaN       NaN   NaN
# 4  Dezapelisib       NaN    0.0  Incyte Corporation   NaN       NaN   NaN
#
#    RoF     MW  LogP  ...                   Targets  Kinase_families  \
# 0    0  450.2   2.9  ...                       NaN              NaN
# 1    0  440.2   4.9  ...                       NaN              NaN
# 2    0  337.2   1.5  ...  ['JAK1', 'JAK2', 'JAK3']          ['Tyr']
# 3    0  396.2   3.1  ...                   ['KIT']          ['KIT']
# 4    0  421.1   3.7  ...                       NaN              NaN
#
#    First_Approval  SC_Patent            Chirality  \
# 0             NaN        NaN  Single Stereoisomer
# ...

# %% [markdown]
# ## Load KLIFS ligands in clinical trails

# %%
klifs_pki = pd.read_csv('results/klifs_pki_20200218.csv', index_col=0)
klifs_pki.head()
# Out:
#                       InChIKey      INN_Name BrandName  Phase  \
# 0  MWKYMZXCGYXLPL-ZDUSSCGKSA-N    Leniolisib       NaN    0.0
# 1  MCIDWGZGWVSZMK-UHFFFAOYSA-N   Nemiralisib       NaN    0.0
# 2  RZUOCXOYPYGSKL-GOSISDBHSA-N  Ravoxertinib       NaN    1.0
# 3  CGBJSGAELGCMKE-UHFFFAOYSA-N    Omipalisib       NaN    1.0
# 4  HKTBYUWLRDZAJK-UHFFFAOYSA-N  Tomivosertib       NaN    2.0
#
#               Applicants LigID                     pdbID  Type  RoF     MW  \
# 0               Novartis   9NQ                  ['5o83']   NaN    0  450.2
# 1        GlaxosmithKline   VVX                  ['5ae8']   NaN    0  440.2
# 2              Genentech   6QB  ['5k4i', '5k4j', '6oph']   NaN    0  440.1
# 3        GlaxosmithKline   ZIG                  ['3l08']   1.0    1  505.1
# 4  Effector Therapeutics   N45                  ['6ck6']   NaN    0  340.2
#
#    ...            Chirality                                       Synonyms  \
# ...
